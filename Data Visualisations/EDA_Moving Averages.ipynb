# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lob_data= pd.read_csv("C:/Users/keert/OneDrive/Desktop/Mini Project/resampled_lob_secs2.csv")
lob_data['Datetime'] = pd.to_datetime(lob_data['Datetime'])

lob_data['price']=(lob_data['Max Bid Price']*lob_data['Max Bid Quantity']+lob_data['Min Ask Price']*lob_data['Min Ask Quantity'])/(lob_data['Max Bid Quantity']+lob_data['Min Ask Quantity'])
# lob_data
lob_data
# Out:
#                    Datetime  Min Ask Price  Max Bid Price       price  \
# 0       2025-01-02 00:00:02            310            261  293.666667
# 1       2025-01-02 00:00:03            293            262  269.750000
# 2       2025-01-02 00:00:04            287            264  271.666667
# 3       2025-01-02 00:00:05            283            264  272.636364
# 4       2025-01-02 00:00:06            281            265  267.285714
# ...                     ...            ...            ...         ...
# 3767279 2025-07-01 08:17:55            183            109  133.666667
# 3767280 2025-07-01 08:17:56            183            110  128.250000
# 3767281 2025-07-01 08:17:57            123            110  114.333333
# 3767282 2025-07-01 08:17:58            114            109  111.500000
# 3767283 2025-07-01 08:17:59            112            108  110.000000
#
#          Total Bid Quantity  Total Ask Quantity  Min Ask Quantity  \
# ...

# %%
lob_data=lob_data.dropna()

# %%
# Assuming 'lob_data' has a 'Datetime' column in datetime format
# Calculate the moving averages for Min Ask Price and Max Bid Price
lob_data['Datetime'] = pd.to_datetime(lob_data['Datetime'])
lob_data.set_index('Datetime', inplace=True)

moving_average_span = 10000  # Number of data points to include in the moving average, adjust as necessary
lob_data['Min Ask Price MA'] = lob_data['Min Ask Price'].rolling(window=moving_average_span).mean()
lob_data['Max Bid Price MA'] = lob_data['Max Bid Price'].rolling(window=moving_average_span).mean()

# Plot the moving averages
plt.figure(figsize=(14, 7))
plt.plot(lob_data['Min Ask Price MA'], label='Min Ask Price MA')
plt.plot(lob_data['Max Bid Price MA'], label='Max Bid Price MA', alpha=0.8)
plt.title('Moving Averages of Min Ask Price and Max Bid Price')
plt.xlabel('Datetime')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_17652\3806171587.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lob_data['Datetime'] = pd.to_datetime(lob_data['Datetime'])
# C:\Users\keert\AppData\Local\Temp\ipykernel_17652\3806171587.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lob_data['Min Ask Price MA'] = lob_data['Min Ask Price'].rolling(window=moving_average_span).mean()
# C:\Users\keert\AppData\Local\Temp\ipykernel_17652\3806171587.py:8: SettingWithCopyWarning:
# ...
