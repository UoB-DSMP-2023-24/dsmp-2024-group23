# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Apr 04 10:12:47 2024

@author: keert
"""

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
import seaborn as sns
import ast  # parse string representation of list to list

#read the process resampled_lob_min.csv'.csv  
 
LOB_df = pd.read_csv('C:/Users/keert/OneDrive/Desktop/Mini Project/resampled_lob_min.csv')

pd.options.display.max_columns = None
pd.options.display.max_rows = None

LOB_df.head()

LOB_df['Datetime'] = pd.to_datetime(LOB_df['Datetime'])

# %%
# Time Series Analysis
plt.figure(figsize=(12, 6))
plt.plot(LOB_df['Datetime'], LOB_df['Min Ask Price'], label='Min Ask Price')
plt.plot(LOB_df['Datetime'], LOB_df['Max Bid Price'], label='Max Bid Price')
plt.xlabel('Datetime')
plt.ylabel('Price')
plt.title('Price Trends')
plt.legend()
plt.show()

# %%
# Volume Analysis
plt.figure(figsize=(12, 6))
plt.plot(LOB_df['Datetime'], LOB_df['Total Bid Quantity sum'], label='Total Bid Quantity')
plt.plot(LOB_df['Datetime'], LOB_df['Total Ask Quantity sum'], label='Total Ask Quantity')
plt.xlabel('Datetime')
plt.ylabel('Volume')
plt.title('Volume Dynamics')
plt.legend()
plt.show()

# %%
# Spread Analysis
LOB_df['Spread'] = LOB_df['Min Ask Price'] - LOB_df['Max Bid Price']
plt.figure(figsize=(12, 6))
plt.plot(LOB_df['Datetime'], LOB_df['Spread'])
plt.xlabel('Datetime')
plt.ylabel('Spread')
plt.title('Spread Dynamics')
plt.show()

# %%
# Correlation Analysis
correlation_matrix = LOB_df.corr()
plt.figure(figsize=(8, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_42256\2285119184.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = LOB_df.corr()

# %%
# Plotting relevant graphs
plt.figure(figsize=(10, 7))

# Plot Min Ask Price and Max Bid Price
plt.plot(LOB_df['Datetime'], LOB_df['Min Ask Price'], label='Min Ask Price', color='blue')
plt.plot(LOB_df['Datetime'], LOB_df['Max Bid Price'], label='Max Bid Price', color='orange')
plt.xlabel('Datetime')
plt.ylabel('Price')
plt.title('Min Ask Price vs Max Bid Price')
plt.show()

# %%
# Plotting spread (difference between Max Bid Price and Min Ask Price)
plt.figure(figsize=(10, 7))

plt.plot(LOB_df['Datetime'], LOB_df['Spread'], label='Spread', color='purple')
plt.xlabel('Datetime')
plt.ylabel('Spread')
plt.title('Spread (Max Bid Price - Min Ask Price)')
plt.show()
